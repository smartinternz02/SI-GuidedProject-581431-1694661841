# %% [markdown]
# # **8TH_SEPT_ASSIGNMENT**

# %% [markdown]
# NAME:-  K S H V SAI HARI KRISHNA
#
#
# REG NO:- 21BCE8069

# %%
Assignment 8 th september
1.Take car crashes dataset from seaborn library
2.load the dataset
3.data visualiation
4.Inference is must for each and every graph
5.Submit it by wednesday in html format

Feedback - https://forms.gle/7vFfvANDVfvDxxW28

# %% [markdown]
# # Steps:
# 1.import the necessary libraries
# 2.import the dataset
# 3.Handling null values
# 4.Seperate Dependent and independent variables
# 5.Encoding
# 6.splitting into training and testing set
# 7.Feature scaling

# %% [markdown]
# ## 1.import the necessary libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## 2.import the dataset

# %%
print(sns.get_dataset_names())
# Out:
# ['anagrams', 'anscombe', 'attention', 'brain_networks', 'car_crashes', 'diamonds', 'dots', 'dowjones', 'exercise', 'flights', 'fmri', 'geyser', 'glue', 'healthexp', 'iris', 'mpg', 'penguins', 'planets', 'seaice', 'taxis', 'tips', 'titanic']

# %%
df=sns.load_dataset('car_crashes')

# %%
df
# Out:
#     total  speeding  alcohol  not_distracted  no_previous  ins_premium  \
# 0    18.8     7.332    5.640          18.048       15.040       784.55
# 1    18.1     7.421    4.525          16.290       17.014      1053.48
# 2    18.6     6.510    5.208          15.624       17.856       899.47
# 3    22.4     4.032    5.824          21.056       21.280       827.34
# 4    12.0     4.200    3.360          10.920       10.680       878.41
# 5    13.6     5.032    3.808          10.744       12.920       835.50
# 6    10.8     4.968    3.888           9.396        8.856      1068.73
# 7    16.2     6.156    4.860          14.094       16.038      1137.87
# 8     5.9     2.006    1.593           5.900        5.900      1273.89
# 9    17.9     3.759    5.191          16.468       16.826      1160.13
# 10   15.6     2.964    3.900          14.820       14.508       913.15
# 11   17.5     9.450    7.175          14.350       15.225       861.18
# ...

# %%
sns.__version__
# Out:
# '0.12.2'

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   total           51 non-null     float64
#  1   speeding        51 non-null     float64
#  2   alcohol         51 non-null     float64
#  3   not_distracted  51 non-null     float64
#  4   no_previous     51 non-null     float64
#  5   ins_premium     51 non-null     float64
#  6   ins_losses      51 non-null     float64
#  7   abbrev          51 non-null     object
# dtypes: float64(7), object(1)
# memory usage: 3.3+ KB

# %%
df.head()
# Out:
#    total  speeding  alcohol  not_distracted  no_previous  ins_premium  \
# 0   18.8     7.332    5.640          18.048       15.040       784.55
# 1   18.1     7.421    4.525          16.290       17.014      1053.48
# 2   18.6     6.510    5.208          15.624       17.856       899.47
# 3   22.4     4.032    5.824          21.056       21.280       827.34
# 4   12.0     4.200    3.360          10.920       10.680       878.41
#
#    ins_losses abbrev
# 0      145.08     AL
# 1      133.93     AK
# 2      110.35     AZ
# 3      142.39     AR
# 4      165.63     CA

# %%
df.shape
# Out:
# (51, 8)

# %%
sns.scatterplot(x="total",y="speeding",data=df)

print("as speed increases total also increases")
# Out:
# as speed increases total also increases

# %%
sns.scatterplot(x="speeding",y="alcohol",data=df)

print("as alcohol increases speeding also increases")
# Out:
# as alcohol increases speeding also increases

# %%
sns.scatterplot(x="alcohol",y="not_distracted",data=df)

print("as alcohol increases not_distracted also increases")
# Out:
# as alcohol increases not_distracted also increases

# %%
sns.lineplot(x="total",y="speeding",data=df,ci=None)
print("here we can see fulcutations but still its they are related")
# Out:
# <ipython-input-107-7884c730efd4>:1: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.lineplot(x="total",y="speeding",data=df,ci=None)
# here we can see fulcutations but still its they are related

# %%
sns.lineplot(x="alcohol",y="not_distracted",data=df,ci=None)
print("here we can see fulcutations but still its they are related")
# Out:
# <ipython-input-109-ee6c7a76b6a6>:1: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.lineplot(x="alcohol",y="not_distracted",data=df,ci=None)
# here we can see fulcutations but still its they are related

# %%
sns.lineplot(x="no_previous",y="ins_premium",data=df,ci=None)
print("here we can see fulcutations but still its they are related")
# Out:
# <ipython-input-110-0c2ff91edc84>:1: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.lineplot(x="no_previous",y="ins_premium",data=df,ci=None)
# here we can see fulcutations but still its they are related

# %%
sns.distplot(df["total"])
print("data distribution of a total against the density distribution")
# Out:
# <ipython-input-115-1eedb4648a09>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df["total"])
# data distribution of a total against the density distribution

# %%
sns.distplot(df["alcohol"])
print("data distribution of alcohol against the density distribution")
# Out:
# <ipython-input-117-6f9e972c38d5>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df["alcohol"])
# data distribution of alcohol against the density distribution

# %%
sns.distplot(df["no_previous"])
print("data distribution of a no_previous against the density distribution")
# Out:
# <ipython-input-118-84f63674cc34>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df["no_previous"])
# data distribution of a no_previous against the density distribution

# %%
sns.relplot(x="total",y="speeding",data=df,hue="alcohol")
print("using hue we differentiated different categories with colors")
# Out:
# using hue we differentiated different categories with colors

# %%
sns.relplot(x="not_distracted",y="no_previous",data=df,hue="ins_premium")
print("using hue we differentiated different categories with colors")
# Out:
# using hue we differentiated different categories with colors

# %%
sns.relplot(x="total",y="speeding",data=df,hue="abbrev")
print("using hue we differentiated different categories with colors")
# Out:
# using hue we differentiated different categories with colors

# %%
print("here we get count of all categories. has everything repeated ")
# Out:
# here we get count of all categories. has everything repeated

# %%
df["speeding"].value_counts()
# Out:
# 4.968    2
# 7.332    1
# 9.100    1
# 5.439    1
# 4.060    1
# 1.792    1
# 3.496    1
# 3.936    1
# 6.552    1
# 5.497    1
# 3.948    1
# 6.368    1
# 4.224    1
# 3.774    1
# 8.346    1
# 9.082    1
# 6.014    1
# 4.095    1
# 7.760    1
# 4.859    1
# 4.080    1
# 2.413    1
# 4.452    1
# 8.092    1
# 1.937    1
# 6.923    1
# 7.421    1
# 2.640    1
# 6.510    1
# 4.032    1
# 4.200    1
# 5.032    1
# 6.156    1
# 2.006    1
# 3.759    1
# 2.964    1
# 9.450    1
# 5.508    1
# 4.608    1
# 3.625    1
# 2.669    1
# 4.806    1
# 4.066    1
# 7.175    1
# 5.738    1
# 4.250    1
# 1.886    1
# 3.384    1
# 2.208    1
# 7.308    1
# Name: speeding, dtype: int64

# %%
df["not_distracted"].value_counts()
# Out:
# 14.094    2
# 18.048    1
# 17.472    1
# 13.965    1
# 10.092    1
# 9.632     1
# 12.328    1
# 10.824    1
# 15.792    1
# 23.661    1
# 13.959    1
# 18.308    1
# 8.576     1
# 10.212    1
# 17.976    1
# 22.944    1
# 19.012    1
# 15.990    1
# 17.654    1
# 9.944     1
# 13.056    1
# 11.049    1
# 8.692     1
# 23.086    1
# 13.857    1
# 14.812    1
# 16.290    1
# 1.760     1
# 15.624    1
# 21.056    1
# 10.920    1
# 10.744    1
# 9.396     1
# 5.900     1
# 16.468    1
# 14.820    1
# 14.350    1
# 13.005    1
# 12.032    1
# 13.775    1
# 15.229    1
# 13.706    1
# 16.692    1
# 14.965    1
# 13.137    1
# 8.875     1
# 7.134     1
# 13.395    1
# 8.448     1
# 5.382     1
# Name: not_distracted, dtype: int64

# %%
df["no_previous"].value_counts()
# Out:
# 12.920    2
# 15.040    1
# 16.016    1
# 14.553    1
# 9.628     1
# 8.736     1
# 18.032    1
# 9.840     1
# 13.608    1
# 20.554    1
# 11.562    1
# 18.706    1
# 11.520    1
# 8.769     1
# 18.190    1
# 19.359    1
# 16.684    1
# 15.795    1
# 16.878    1
# 10.848    1
# 11.176    1
# 9.116     1
# 20.706    1
# 11.592    1
# 13.410    1
# 13.524    1
# 17.014    1
# 17.600    1
# 17.856    1
# 21.280    1
# 10.680    1
# 8.856     1
# 16.038    1
# 5.900     1
# 16.826    1
# 14.508    1
# 15.225    1
# 14.994    1
# 12.288    1
# 13.775    1
# 13.659    1
# 15.130    1
# 16.264    1
# 20.090    1
# 12.684    1
# 12.375    1
# 6.560     1
# 10.857    1
# 8.448     1
# 15.660    1
# Name: no_previous, dtype: int64

# %%
print("Bargraph :total vs sppeding")
print("Bargraph : alcohol vs not_distracted ")
print("Bargraph :no_previous vs ins_premium ")
# Out:
# Bargraph :total vs sppeding
# Bargraph : alcohol vs not_distracted
# Bargraph :no_previous vs ins_premium

# %%
sns.barplot(data=df,x="total",y="speeding",ci=None)
# Out:
# <ipython-input-84-45580ba4c45b>:1: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(data=df,x="total",y="speeding",ci=None)
# <Axes: xlabel='total', ylabel='speeding'>

# %%
sns.barplot(data=df,x="alcohol",y="not_distracted",ci=None)
# Out:
# <ipython-input-85-c836539ef2b1>:1: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(data=df,x="alcohol",y="not_distracted",ci=None)
# <Axes: xlabel='alcohol', ylabel='not_distracted'>

# %%
sns.barplot(data=df,x="no_previous",y="ins_premium",ci=None)
# Out:
# <ipython-input-86-560e315f829c>:1: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(data=df,x="no_previous",y="ins_premium",ci=None)
# <Axes: xlabel='no_previous', ylabel='ins_premium'>

# %%
sns.barplot(data=df,x="alcohol",y="not_distracted",hue="no_previous")
# Out:
# <Axes: xlabel='alcohol', ylabel='not_distracted'>

# %%
sns.barplot(data=df,x="alcohol",y="not_distracted",hue="ins_premium")
# Out:
# <Axes: xlabel='alcohol', ylabel='not_distracted'>

# %%
print("countplot for : total ")
print("countplot for : alcohol ")
print("countplot for : not_distracted ")
# Out:
# countplot for : total
# countplot for : alcohol
# countplot for : not_distracted

# %%
sns.countplot(x="total",data=df)
# Out:
# <Axes: xlabel='total', ylabel='count'>

# %%
sns.countplot(x="alcohol",data=df)
# Out:
# <Axes: xlabel='alcohol', ylabel='count'>

# %%
sns.countplot(x="not_distracted",data=df)
# Out:
# <Axes: xlabel='not_distracted', ylabel='count'>

# %%
print("jointplot for : total vs speeding ")
print("jointplot for : alcohol  vs no previous  ")
print("jointplot for : not_distracted  vs no previous ")
# Out:
# jointplot for : total vs speeding
# jointplot for : alcohol  vs no previous
# jointplot for : not_distracted  vs no previous

# %%
sns.jointplot(x="total",y="speeding",data=df)

# %%
sns.jointplot(x="alcohol",y="no_previous",data=df)

# %%
sns.jointplot(x="not_distracted",y="no_previous",data=df)

# %%
sns.boxplot(x="total",y="speeding",data=df)
# Out:
# <Axes: xlabel='total', ylabel='speeding'>

# %%
sns.boxplot(x="not_distracted",y="total",data=df)
# Out:
# <Axes: xlabel='not_distracted', ylabel='total'>

# %%
sns.boxplot(x="not_distracted",y="ins_premium",data=df)
# Out:
# <Axes: xlabel='not_distracted', ylabel='ins_premium'>

# %%
corr=df.corr()
corr
# Out:
# <ipython-input-98-7d5195e2bf4d>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr=df.corr()
#                    total  speeding   alcohol  not_distracted  no_previous  \
# total           1.000000  0.611548  0.852613        0.827560     0.956179
# speeding        0.611548  1.000000  0.669719        0.588010     0.571976
# alcohol         0.852613  0.669719  1.000000        0.732816     0.783520
# not_distracted  0.827560  0.588010  0.732816        1.000000     0.747307
# no_previous     0.956179  0.571976  0.783520        0.747307     1.000000
# ins_premium    -0.199702 -0.077675 -0.170612       -0.174856    -0.156895
# ins_losses     -0.036011 -0.065928 -0.112547       -0.075970    -0.006359
#
#                 ins_premium  ins_losses
# total             -0.199702   -0.036011
# ...

# %%
sns.heatmap(corr,annot=True,cmap="YlGnBu")
# Out:
# <Axes: >

# %%
x=df["alcohol"]
y = df["speeding"]
plt.bar(x,y)
# Out:
# <BarContainer object of 51 artists>

# %%
plt.barh(x,y)
# Out:
# <BarContainer object of 51 artists>

# %%
plt.barh(x,y,color = 'black')
# Out:
# <BarContainer object of 51 artists>

# %%
plt.bar(x,y,width = 0.25)
# Out:
# <BarContainer object of 51 artists>

# %%
plt.hist(x)
# Out:
# (array([ 2.,  3., 13., 13., 11.,  2.,  4.,  0.,  0.,  3.]),
#  array([ 1.593 ,  2.4375,  3.282 ,  4.1265,  4.971 ,  5.8155,  6.66  ,
#          7.5045,  8.349 ,  9.1935, 10.038 ]),
#  <BarContainer object of 10 artists>)

# %%
x1 =(df["alcohol"])
fig = plt.figure()
axes1 = fig.add_axes([0.1,0.1,0.8,0.8])
axes1.pie(x1,y,autopct="%0.2f%%",colors=["red","green"])
# Out:
# ([<matplotlib.patches.Wedge at 0x7d15bcce7730>,
# ...
#  [Text(8.410699544034177, 0.5989634212398267, ''),
#   Text(8.352451213487306, 1.686416237562493, ''),
#   Text(7.219080145466262, 2.4076922256249467, ''),
#   Text(4.596307879757315, 2.282844251034401, ''),
#   Text(4.442676050348083, 2.8900916095625004, ''),
#   Text(4.8174064272344586, 3.7939450859020254, ''),
#   Text(4.381069891848447, 4.198434303730266, ''),
#   Text(4.654492093706887, 5.566438659468016, ''),
#   Text(1.7922050148895288, 2.5367769284280444, ''),
#   Text(2.4545111102703068, 4.193477817940573, ''),
#   Text(1.638404163601255, 3.7191030903558016, ''),
#   Text(2.868396865351445, 10.15257599936302, ''),
#   Text(0.8499282227709963, 6.553112696737128, ''),
#   Text(0.1038203367441988, 5.7070557503565995, ''),
#   Text(-0.423145844593834, 4.706014512748869, ''),
#   Text(-0.7197898051735776, 3.699630202651095, ''),
#   Text(-1.7198394510077382, 5.650043208928353, ''),
# ...
